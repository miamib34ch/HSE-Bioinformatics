# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/log.csv', sep = ';')
df = df.replace(',', '.', regex=True)
df = df.astype(float)
df = df.rename(index={0: 'HR', 1: 'H2A', 2: 'H2B', 3: 'H3', 4: 'H4'})
df
# Out:
#       human   mouse  zebrafish  drosophila  c.elegans  ciliate  yeast  \
# HR   300.00  300.00      49.57       29.98       0.00     1.04   0.57
# H2A  300.00  300.00     300.00       43.91      47.06    45.91  45.06
# H2B  105.99   28.03      26.95       25.94      26.69    25.24  26.37
# H3    95.66   95.81      94.75       95.03      93.35    85.08  86.48
# H4    66.96   67.12      67.95       67.10      67.21    44.71  51.97
#
#      methanocaldococcus  thermococcus  e.coli  tuberculosis
# HR                -0.77         -0.15   -0.36         -0.92
# H2A                0.59          5.16   13.88          1.00
# H2B                1.19          0.27    0.82         -0.38
# H3                 1.47          1.24    0.05         -0.66
# H4                 4.09          4.48   -0.11          1.16

# %%
f, ax = plt.subplots(figsize=(20,5))
colors = ['#000000','#1c001a','#290026','#40003b','#52024b','#b700cf','#ffffff']
ax = sns.heatmap(df, cmap = colors, annot = df)
ax.set_yticklabels(df.index.values)
plt.show()
