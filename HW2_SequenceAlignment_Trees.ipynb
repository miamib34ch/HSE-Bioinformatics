# %% [markdown]
# **Домашняя работа №2. Полыгалов Богдан, группа 2.**

# %% [markdown]
# Выбрать ген (Можно ориентироваться на Table 1 из https://www.ncbi.nlm.nih.gov/pmc/articles/PMC430263/ , гены субъединиц атфазы, полимераз, рибосомальных белков).
# <br>Минимальное число видов, необходимых для включения в дерево – 10.
# Найти аминокислотные последовательности генов для нижеперечисленных видов и составить fasta-файл с последовательностями. Поставьте в начало названия гена строку с названием организма, чтобы организм отображался на листьях дерева. Например.
# >Bacterium  AHI16583.1 ATP synthase alpha [Lactobacillus sp. HRROT3]
#
# Хорошо бы иметь представленность следующих видов:
#
# >Человек - human
# <br>Обезьяна - primates
# <br>Грызуны - mouse, rat
# <br>Копытное -   bovine
# <br>Сумчатое - marsupials
# <br>Пресмыкающиеся - snakes, lizards, turtles
# <br>Птица
# <br>Рыба
# <br>Растение
# <br>Пекарские дрожжи - fungi (Saccharomyces cerevisiae)
# <br>Архея - archaea
# <br>Бактерия - bacteria
#
# Поиск гена производится на сайте NCBI в базе данных “protein”.
# <br>Вбиваете название гена: (ribosomal protein L1) + используйте кнопку Advanced для лучшего поиска.

# %% [markdown]
# Выбранный ген - ribosomal protein L34

# %% [markdown]
# # **Выравнивания**

# %% [markdown]
# **Произвести множественное выравнивание последовательностей алгоритмами ClustalW и Muscle  из пакета Mega. Сохранить два выравнивания в отдельные файлы. Написать, есть ли разница в выравнивании.**
#
# Множественное выравнивание последовательностей алгоритмом ClustalW:
# ![image.png](data:image/png;base64,...)
#
# Множественное выравнивание последовательностей алгоритмом Muscle:
# ![image.png](data:image/png;base64,...)
#
# Разница в выравнивании есть:
# 1.	Количества гэпов больше в Muscle, также в Muscle больше длина выравнивания.
# 2.	В Muscle гэпы краевые (правый край), на семинарах говорили, что лучше выравнивания, где гэпы не с краёв. В ClustalW больше не краевых, а внутренних.
# 3.	В Muscle больше консервативных сайтов (при выставлении параметра в меге на выделение). Хотя полностью совпадающих участков всего 1 в обоих выравниваниях.

# %% [markdown]
# # **Деревья**

# %% [markdown]
# В программе Mega построить филогенетическое дерево для аминокислотных последовательностей с бутсрэп-анализом для двух выравниваний – и методом ClustalW, и Muscle.
# 1. Методом расстояний (UPGMA)
# 2. Методом расстояний (NJ)
# 3. Методом максимального правдоподобия

# %% [markdown]
# ## **Скриншоты Bootstrap consensus tree**

# %% [markdown]
# CW ML:
#
# ![CW ML.png](data:image/png;base64,...)
#
# CW NJ:
#
# ![CW NJ.png](data:image/png;base64,...)
#
# CW UPGMA:
#
# ![CW UPGMA.png](data:image/png;base64,...)
#
# M ML:
#
# ![M ML.png](data:image/png;base64,...)
#
# M NJ:
#
# ![M NJ.png](data:image/png;base64,...)
#
# M UPGMA:
#
# ![M UPGMA.png](data:image/png;base64,...)

# %% [markdown]
# ## **Скриншоты Original tree**

# %% [markdown]
# CW ML:
#
# ![CW ML.png](data:image/png;base64,...)
#
# CW NJ:
#
# ![CW NJ.png](data:image/png;base64,...)
#
# CW UPGMA:
#
# ![CW UPGMA.png](data:image/png;base64,...)
#
# M ML:
#
# ![M ML.png](data:image/png;base64,...)
#
# M NJ:
#
# ![M NJ.png](data:image/png;base64,...)
#
# M UPGMA:
#
# ![M UPGMA.png](data:image/png;base64,...)

# %% [markdown]
# # **Выводы**

# %% [markdown]
# 1. Какой алгоритм выравнивания лучше сработал -  ClustalW или Muscle?
# 2. Одинаковая ли получилась топология деревьев при построении разными методами?
# 3. Одинаковые ли получились бутстрэп-значения?
# 4. Совпадают ли деревья, построенные по одному гену с принятыми деревьями видов?

# %% [markdown]
# Сработал лучше алгоритм выравнивания Muscle, поскольку больше совпадающих участков (на основе третьего пункта в главе "Выравнивание").
#
# При построении разными методами топология деревьев получилась:
# 1. Для выравнивания алгоритмом ClustalW разная.
# 2. Для выравнивания алгоритмом Muscle тоже разная, но деревья, построенные методами ML и NJ, практически похожи.
#
# Бутстрэп-значения получились практически одинаковыми, есть небольшие отклонения в +-2. Есть значения меньше 55, что говорит о неправдоподобности построенных вариантов. Скриншоты без бутстреп-значения меньше 55: СW UPGMA, M ML.
#
# Принятое дерево с выбранными видами:
#
# ![image.png](data:image/png;base64,...)
#
# Больше всего совпадений у деревьев CW ML, M NJ, M ML (по названию скриншотов). Но у этих скриншотов, кроме M ML, есть бутстреп-значения ниже 55.
#
# Как видно, эволюция гена расходится с принятой эволюцией видов.
